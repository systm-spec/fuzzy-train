# %%
import pandas as pd
import matplotlib.pyplot as plt


# Dataset
pokemon_dataset = pd.read_csv('../data/pokedex_420.csv')

pkmn_global = pokemon_dataset.drop(['Unnamed: 0', 'name', 'japanese_name', 'catch_rate', 'base_experience',
                                    'base_friendship', 'growth_rate', 'egg_cycles', 'egg_type_1', 'egg_type_2',
                                    'egg_type_number', 'percentage_male'], axis=1)

df = pkmn_global[pkmn_global['generation'] <= 3]
df = df[(df['is_legendary'] == 0) & (df['is_mythical'] == 0)]

# %%
# Scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(df['attack'], df['speed'], alpha=0.5, c='blue', edgecolor='k')


plt.title('Angriff vs. Geschwindigkeit', fontsize=16)
plt.xlabel('Angriff', fontsize=12)
plt.ylabel('Geschwindigkeit', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
df
# Out:
#      pokedex_number german_name  generation  is_sub_legendary  is_legendary  \
# 0                 1     Bisasam           1                 0             0
# 1                 2   Bisaknosp           1                 0             0
# 2                 3    Bisaflor           1                 0             0
# 3                 3    Bisaflor           1                 0             0
# 4                 4    Glumanda           1                 0             0
# ..              ...         ...         ...               ...           ...
# 459             385     Jirachi           3                 0             0
# 460             386      Deoxys           3                 0             0
# 461             386      Deoxys           3                 0             0
# 462             386      Deoxys           3                 0             0
# 463             386      Deoxys           3                 0             0
#
#      is_mythical         species  type_number   type_1   type_2  ...  \
# 0              0    Seed Pokémon            2    Grass   Poison  ...
# 1              0    Seed Pokémon            2    Grass   Poison  ...
# 2              0    Seed Pokémon            2    Grass   Poison  ...
# 3              0    Seed Pokémon            2    Grass   Poison  ...
# 4              0  Lizard Pokémon            1     Fire      NaN  ...
# ..           ...             ...          ...      ...      ...  ...
# 459            1    Wish Pokémon            2    Steel  Psychic  ...
# 460            1     DNA Pokémon            1  Psychic      NaN  ...
# 461            1     DNA Pokémon            1  Psychic      NaN  ...
# 462            1     DNA Pokémon            1  Psychic      NaN  ...
# 463            1     DNA Pokémon            1  Psychic      NaN  ...
#
#      against_ground  against_flying  against_psychic against_bug against_rock  \
# 0               1.0             2.0             2.00         1.0          1.0
# 1               1.0             2.0             2.00         1.0          1.0
# 2               1.0             2.0             2.00         1.0          1.0
# 3               1.0             2.0             2.00         1.0          1.0
# 4               2.0             1.0             1.00         0.5          2.0
# ..              ...             ...              ...         ...          ...
# 459             2.0             0.5             0.25         1.0          0.5
# 460             1.0             1.0             0.50         2.0          1.0
# 461             1.0             1.0             0.50         2.0          1.0
# 462             1.0             1.0             0.50         2.0          1.0
# 463             1.0             1.0             0.50         2.0          1.0
#
#     against_ghost  against_dragon  against_dark  against_steel  against_fairy
# 0             1.0             1.0           1.0            1.0            0.5
# 1             1.0             1.0           1.0            1.0            0.5
# 2             1.0             1.0           1.0            1.0            0.5
# 3             1.0             1.0           1.0            1.0            0.5
# 4             1.0             1.0           1.0            0.5            0.5
# ..            ...             ...           ...            ...            ...
# 459           2.0             0.5           2.0            0.5            0.5
# 460           2.0             1.0           2.0            1.0            1.0
# 461           2.0             1.0           2.0            1.0            1.0
# 462           2.0             1.0           2.0            1.0            1.0
# 463           2.0             1.0           2.0            1.0            1.0
#
# [464 rows x 41 columns]

# %%
df = df[(df['is_legendary'] == 0) & (df['is_mythical'] == 0)]
df[['german_name', "attack", 'speed']].sort_values(["attack", 'speed'], ascending=False).head(20)
# Out:
#     german_name  attack  speed
# 258   Skaraborn   185.0   75.0
# 419     Banette   165.0   75.0
# 295    Despotar   164.0   71.0
# 306     Lohgock   160.0  100.0
# 342   Letarking   160.0  100.0
# 162      Pinsir   155.0  105.0
# 166     Garados   155.0   81.0
# 19        Bibor   150.0  145.0
# 425       Absol   150.0  115.0
# 255     Scherox   150.0   75.0
# 310      Sumpex   150.0   70.0
# 441  Brutalanda   145.0  120.0
# 445   Metagross   145.0  110.0
# 378     Tohaido   140.0  105.0
# 362    Stolloss   140.0   50.0
# 180  Aerodactyl   135.0  150.0
# 440  Brutalanda   135.0  100.0
# 444   Metagross   135.0   70.0
# 187    Dragoran   134.0   80.0
# 294    Despotar   134.0   61.0

# %%
df = df[(df['is_legendary'] == 0) & (df['is_mythical'] == 0)]
df[['german_name', "attack", 'speed']].sort_values([ 'speed', "attack"], ascending=False).head(20)
# Out:
#     german_name  attack  speed
# 344     Ninjask    90.0  160.0
# 180  Aerodactyl   135.0  150.0
# 84      Simsala    50.0  150.0
# 130   Lektrobal    50.0  150.0
# 19        Bibor   150.0  145.0
# 302    Gewaldro   110.0  145.0
# 368    Voltenso    75.0  135.0
# 179  Aerodactyl   105.0  130.0
# 209      Iksbat    90.0  130.0
# 123      Gengar    65.0  130.0
# 172      Blitza    65.0  130.0
# 329  Schwalboss    85.0  125.0
# 23      Tauboss    80.0  121.0
# 441  Brutalanda   145.0  120.0
# 65       Digdri   100.0  120.0
# 301    Gewaldro    85.0  120.0
# 33      Pikachu    80.0  120.0
# 83      Simsala    50.0  120.0
# 425       Absol   150.0  115.0
# 259     Sniebel    95.0  115.0
