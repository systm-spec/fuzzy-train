# %%
import pandas as pd
import matplotlib.pyplot as plt

pokemon_dataset = pd.read_csv('../src/data/pokedex_420.csv')

pkmn_global = pokemon_dataset.drop(['Unnamed: 0','name', 'japanese_name', 'catch_rate', 'base_experience',
                                    'base_friendship', 'growth_rate', 'egg_cycles', 'egg_type_1', 'egg_type_2',
                                    'egg_type_number', 'percentage_male'],axis=1)

pkmn = pkmn_global[pkmn_global['generation'] <= 3]

# %%
# größten Pokemon herausgefiltert
groeste_pkmn = pkmn[['german_name', 'height_m']]
groesten_fuenf = groeste_pkmn.sort_values(by=['height_m'], ascending=False)
top_5_groeste = groesten_fuenf.head()
top_5_groeste
# Out:
#     german_name  height_m
# 380     Wailord      14.5
# 133     Kokowei      10.9
# 458    Rayquaza      10.8
# 250     Stahlos      10.5
# 454      Kyogre       9.8

# %%
# ein Diagramm für die größten fünf Pokemons erstellt
plt.figure(figsize=(6,4))
plt.bar(top_5_groeste["german_name"], top_5_groeste["height_m"], color='orange', ec='black')
plt.title("Die fünf größten Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Grösse (m)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# kleinsten Pokemons herausgefiltert
kleinste_pkmn = pkmn[['german_name', 'height_m']]
kleinsten_fuenf = kleinste_pkmn.sort_values(by=['height_m'], ascending=True)
flop_fuenf = kleinsten_fuenf.head()
flop_fuenf
# Out:
#     german_name  height_m
# 64        Digda       0.2
# 63        Digda       0.2
# 351     Azurill       0.2
# 217        Natu       0.2
# 28      Habitak       0.3

# %%
# Erstellung eines Diagramms für die fünf kleinsten Pokemons
plt.figure(figsize=(6,4))
plt.bar(flop_fuenf["german_name"], flop_fuenf["height_m"], color='green', ec='brown')
plt.title("Die fünf kleinsten Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Grösse (m)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# herausfiltern der schwersten Pokemons
schwerste_pkmn = pkmn[['german_name', 'weight_kg']]
schwersten_fuenf = schwerste_pkmn.sort_values(by=['weight_kg'], ascending=False)
top_5_gewicht = schwersten_fuenf.head(5)
top_5_gewicht
# Out:
#     german_name  weight_kg
# 456     Groudon      999.7
# 455     Groudon      950.0
# 445   Metagross      942.9
# 250     Stahlos      740.0
# 444   Metagross      550.0

# %%
# ein Diagramm der schwersten fünf Pokemons erstellt
farben = ['blue', 'red', 'green', 'yellow', 'black']
plt.figure(figsize=(6,4))
plt.bar(top_5_gewicht["german_name"], top_5_gewicht["weight_kg"], color=farben, ec='black')
plt.title("Die fünf schwersten Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Körpergewicht (kg)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# herausfiltern der leichtesten Pokemons
leichteste_pkmn = pkmn[['german_name', 'weight_kg']]
leichtesten_fuenf = leichteste_pkmn.sort_values(by=['weight_kg'], ascending=True)
flop_5_gewicht = leichtesten_fuenf.head()
flop_5_gewicht
# Out:
#     german_name  weight_kg
# 120     Nebulak        0.1
# 121     Alpollo        0.1
# 267    Corasonn        0.5
# 228  Hoppspross        0.5
# 415      Formeo        0.8

# %%
# erstellen eines Diagramms mit den fünf leichtesten Pokemons
plt.figure(figsize=(6,4))
plt.bar(flop_5_gewicht["german_name"], flop_5_gewicht["weight_kg"], color='navy', ec='black')
plt.title("Die fünf leichtesten Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Körpergewicht (kg)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# herausfiltern der schnellsten Pokemons
schnellste_pkmn = pkmn[['german_name', 'speed']]
schnellsten_fuenf = schnellste_pkmn.sort_values(by=['speed'], ascending=False)
top_5_speed = schnellsten_fuenf.head(7)
top_5_speed
# Out:
#     german_name  speed
# 463      Deoxys  180.0
# 344     Ninjask  160.0
# 460      Deoxys  150.0
# 461      Deoxys  150.0
# 84      Simsala  150.0
# 130   Lektrobal  150.0
# 180  Aerodactyl  150.0

# %%
# erstellen eines Diagramms mit den fünf schnellsten Pokemons
plt.figure(figsize=(6,4))
plt.bar(top_5_speed["german_name"], top_5_speed["speed"], color='red', ec='black')
plt.title("Die fünf schnellsten Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Geschwindigkei (m/s)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# die langsamsten Pokemons herausgefiltert
langsamste_pkmn = pkmn[['german_name', 'speed']]
langsamsten_fuenf = langsamste_pkmn.sort_values(by=['speed'], ascending=True)
flop_5_speed = langsamsten_fuenf.head()
flop_5_speed
# Out:
#     german_name  speed
# 256    Pottrott    5.0
# 388   Knacklion   10.0
# 235      Felino   15.0
# 103     Flegmon   15.0
# 320     Panekon   15.0

# %%
# ein Diagramm mit den langsamsten Pokemons erstellt
plt.figure(figsize=(6,4))
plt.bar(flop_5_speed["german_name"], flop_5_speed["speed"], color='blue', ec='black')
plt.title("Die fünf langsamsten Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Geschwindigkeit (m/s)", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem höchsten Energielevel herausgefiltert
hoechster_energy_pkmn = pkmn[['german_name', 'hp']]
hoechsten_fuenf_energy = hoechster_energy_pkmn.sort_values(by=['hp'], ascending=False)
top_5_energie = hoechsten_fuenf_energy.head()
top_5_energie
# Out:
#     german_name     hp
# 288    Heiteira  255.0
# 145    Chaneira  250.0
# 243   Woingenau  190.0
# 380     Wailord  170.0
# 181      Relaxo  160.0

# %%
# ein Diagramm mit den Pokemons mit dem höchsten Energielevel erstellt
plt.figure(figsize=(6,4))
plt.bar(top_5_energie["german_name"], top_5_energie["hp"], color='brown',ec='black')
plt.title("Die fünf höchsten energetischen Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Energiewerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem niedrigsten Energielevel herausgefiltert
niedrigste_energy_pkmn = pkmn[['german_name', 'hp']]
niedrigsten_fuenf_energy = niedrigste_energy_pkmn.sort_values(by=['hp'], ascending=True)
flop_5_energie = niedrigsten_fuenf_energy.head(6)
flop_5_energie
# Out:
#     german_name    hp
# 345    Ninjatom   1.0
# 63        Digda  10.0
# 64        Digda  10.0
# 420  Zwirrlicht  20.0
# 256    Pottrott  20.0
# 212       Pichu  20.0

# %%
# ein Diagramm mit den Pokemons mit dem niedrigsten Energielevel erstellt
plt.figure(figsize=(6,4))
plt.bar(flop_5_energie["german_name"], flop_5_energie["hp"], color='skyblue', ec='black')
plt.title("Die fünf niedrigsten ernegetischen Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Energiewerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem stärkstem Angriff herausgefiltert
staerkste_angriff_pkmn = pkmn[['german_name', 'attack']]
staerksten_fuenf_angriff = staerkste_angriff_pkmn.sort_values(by=['attack'], ascending=False)
top_5_angreifer = staerksten_fuenf_angriff.head(5)
top_5_angreifer
# Out:
#     german_name  attack
# 189       Mewtu   190.0
# 258   Skaraborn   185.0
# 458    Rayquaza   180.0
# 456     Groudon   180.0
# 461      Deoxys   180.0

# %%
# ein Diagramm mit den Pokemons mit dem stärkstem Angriffswert erstellt
plt.figure(figsize=(6, 4))
plt.bar(top_5_angreifer["german_name"], top_5_angreifer["attack"], color= 'red', ec='black')
plt.title("Die fünf angriffstärksten Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Angriffswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem schwächstem Angriff herausgefiltert
schwaechste_angriff_pkmn = pkmn[['german_name', 'attack']]
schwaechsten_fuenf_angriff = schwaechste_angriff_pkmn.sort_values(by=['attack'], ascending=True)
flop_5_angreifer = schwaechsten_fuenf_angriff.head(5)
flop_5_angreifer
# Out:
#     german_name  attack
# 145    Chaneira     5.0
# 256    Pottrott    10.0
# 288    Heiteira    10.0
# 164    Karpador    10.0
# 410    Barschwa    15.0

# %%
# ein Diagramm mit den Pokemons mit dem schwächsten Angriffswert erstellt
plt.figure(figsize=(6, 4))
plt.bar(flop_5_angreifer["german_name"], flop_5_angreifer["attack"], color='grey', ec='black')
plt.title("Die fünf angriffschwächsten Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Angriffswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem stärkstem Defensivwert herausgefiltert
staerkste_defensive_pkmn = pkmn[['german_name', 'defense']]
staerksten_fuenf_defensive = staerkste_defensive_pkmn.sort_values(by=['defense'], ascending=False)
top_5_verteidiger = staerksten_fuenf_defensive.head(7)
top_5_verteidiger
# Out:
#     german_name  defense
# 362    Stolloss    230.0
# 250     Stahlos    230.0
# 256    Pottrott    230.0
# 249     Stahlos    200.0
# 446    Regirock    200.0
# 361    Stolloss    180.0
# 105      Lahmus    180.0

# %%
# ein Diagramm mit den Pokemons mit dem stärkstem Defensivswert erstellt
plt.figure(figsize=(6,4))
plt.bar(top_5_verteidiger["german_name"], top_5_verteidiger["defense"], color='brown', ec='black')
plt.title("Die fünf defensivstärksten Pokémon", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Verteidigungswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pokemons mit dem schwächsten Defensivwert herausgefiltert
schwaechste_defensive_pkmn = pkmn[['german_name', 'defense']]
schwaechste_fuenf_defensive = schwaechste_defensive_pkmn.sort_values(by=['defense'], ascending=True)
flop_5_verteidiger = schwaechste_fuenf_defensive.head()
flop_5_verteidiger
# Out:
#     german_name  defense
# 145    Chaneira      5.0
# 288    Heiteira     10.0
# 81         Abra     15.0
# 212       Pichu     15.0
# 284    Kussilla     15.0

# %%
# ein Diagramm mit den Pokemons mit dem schwächstem Defensivswert erstellt
plt.figure(figsize=(6,4))
plt.bar(flop_5_verteidiger["german_name"], flop_5_verteidiger["defense"], color='darkgreen', ec='brown')
plt.title("Die fünf verteidigungschwästen Pokémon", fontsize=14, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Verteidigungswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# die Pokemons mit dem stärkstem Spezialangriff herausgefiltert
staerkste_spezialangriff_pkmn = pkmn[['german_name', 'sp_attack']]
staerksten_fuenf_spezialangriff = staerkste_spezialangriff_pkmn.sort_values(by=['sp_attack'], ascending=False)
top_5_spezial_angreifer = staerksten_fuenf_spezialangriff.head()
top_5_spezial_angreifer
# Out:
#     german_name  sp_attack
# 190       Mewtu      194.0
# 458    Rayquaza      180.0
# 461      Deoxys      180.0
# 454      Kyogre      180.0
# 84      Simsala      175.0

# %%
# ein Diagramm mit den fünf Pokemons mit dem größten Spezialangriffswert erstellt
farben = ['skyblue', 'lightgreen', 'salmon', 'gold', 'violet']
plt.figure(figsize=(8,5))
plt.bar(top_5_spezial_angreifer["german_name"], top_5_spezial_angreifer["sp_attack"], color=farben , ec= 'black')
plt.title("Die fünf Pokémon mit dem stärksten Spezial-Angriff", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Spezial-Angriffswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# die Pokemons mit dem schwächstem Spezialangriff herausgefiltert
schwaechste_spezialangriff_pkmn = pkmn[['german_name', 'sp_attack']]
schwaechsten_fuenf_spezialangriff = schwaechste_spezialangriff_pkmn.sort_values(by=['sp_attack'], ascending=True)
flop_5_spezial_angreifer = schwaechsten_fuenf_spezialangriff.head()
flop_5_spezial_angreifer
# Out:
#     german_name  sp_attack
# 37       Sandan       10.0
# 410    Barschwa       10.0
# 256    Pottrott       10.0
# 19        Bibor       15.0
# 164    Karpador       15.0

# %%
# ein Diagramm mit den fünf Pokemons mit dem schwächstem Spezialangriffswert erstellt
plt.figure(figsize=(7,5))
plt.bar(flop_5_spezial_angreifer["german_name"], flop_5_spezial_angreifer["sp_attack"], color='darkred', ec='black')
plt.title("Die fünf Pokémon mit schwächsten Spezial-Angriff", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Angriffswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# die Pokemons mit der stärksten Spezialdefensive herausgefiltert
staerkste_spezialdefensive_pkmn = pkmn[['german_name', 'sp_defense']]
staerksten_fuenf_spezialdefensive = staerkste_spezialdefensive_pkmn.sort_values(by=['sp_defense'], ascending=False)
top_5_speziel_verteidiger = staerksten_fuenf_spezialdefensive.head()
top_5_speziel_verteidiger
# Out:
#     german_name  sp_defense
# 256    Pottrott       230.0
# 447      Regice       200.0
# 462      Deoxys       160.0
# 454      Kyogre       160.0
# 296       Lugia       154.0

# %%
# ein Diagramm mit den fünf Pokemons mit dem größtem Spezialdefensivwert erstellt
plt.figure(figsize=(7,5))
plt.bar(top_5_speziel_verteidiger["german_name"], top_5_speziel_verteidiger["sp_defense"], color='violet', ec='black')
plt.title("Die fünf Pokémon mit stärksten Spezial-Verteidigung", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Spezial-Verteidigungswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# die Pokemons mit der schwächsten Spezialdefensive herausgefiltert
schwaechste_spezialdefensive_pkmn = pkmn[['german_name', 'sp_defense']]
schwaechsten_fuenf_spezialdefensive = schwaechste_spezialdefensive_pkmn.sort_values(by=['sp_defense'], ascending=True)
flop_5_spezial_verteidiger = schwaechsten_fuenf_spezialdefensive.head()
flop_5_spezial_verteidiger
# Out:
#     german_name  sp_defense
# 461      Deoxys        20.0
# 376   Kanivanha        20.0
# 164    Karpador        20.0
# 214  Fluffeluff        20.0
# 16      Hornliu        20.0

# %%
# ein Diagramm mit den fünf Pokemons mit dem schwächsten Spezialdefensivwert erstellt
plt.figure(figsize=(7,5))
plt.bar(flop_5_spezial_verteidiger["german_name"], flop_5_spezial_verteidiger["sp_defense"], color='gold', ec='black')
plt.title("Die fünf Pokémon mit schwächsten Spezial-Verteidigung", fontsize=12, fontweight="bold")
plt.xlabel("Pokémon (Deutscher Name)", fontsize=12)
plt.ylabel("Spezial-Verteidigungswerte", fontsize=12)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
